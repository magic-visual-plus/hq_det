# %% [markdown]
# ## model comparer

# %%
import os
from utils import ExperimentInfo, DiffModelTypeComparer

os.chdir(os.path.join(str(globals()['_dh'][0]), "..",))
expers_root = "exper-0606"
os.getcwd(), expers_root
# Out:
# ('/root/hq_det', 'exper-0606')

# %%
info = [
    ExperimentInfo(name="RT-DETRv2 R50", csv_path=f"{expers_root}/rtdetr/results.csv", log_path=f"{expers_root}/rtdetr/nohup.out"),
    ExperimentInfo(name='RTMDet Large', csv_path=f'{expers_root}/rtmdet/results.csv', log_path=f'{expers_root}/rtmdet/nohup.out'),
    ExperimentInfo(name="DINO R50", csv_path=f"{expers_root}/dino/results.csv", log_path=f"{expers_root}/dino/nohup.out"),
    ExperimentInfo(name="CO-DETR R50", csv_path=f"{expers_root}/codetr/results.csv", log_path=f"{expers_root}/codetr/nohup.out"),
    ExperimentInfo(name="YOLOv12 Large", csv_path=f"{expers_root}/yolo12/results.csv", log_path=f"{expers_root}/yolo12/nohup.out"),
    ExperimentInfo(name="RF-DETR Large", csv_path=None, log_path=f"{expers_root}/rfdetr/nohup.out"),
]
comparer = DiffModelTypeComparer(info, training_times=12.0)

# %%
comparer.plot_best_metrics_comparison(figsize=(25, 8))

# %%
comparer.plot_best_metrics_comparison(
    figsize=(25, 8),
    metrics=(
    'mAP',
    # 'precision',
    # 'recall', 
    # 'f1_score',
    # ('AP50', 'AP@50'),
    # ('AP75', 'AP@75'),
    ('AP_small', 'AP Small'),
    ('AP_medium', 'AP Medium'),
    ('AP_large', 'AP Large'),
    ('AR_1', 'AR@1'),
    # ('AR_10', 'AR@10'),
    # ('AR_100', 'AR@100'),
    ('AR_small', 'AR Small'),
    ('AR_medium', 'AR Medium'),
    ('AR_large', 'AR Large')
))

# %%
comparer.plot_loss_comparison()

# %%
comparer.plot_metrics_comparison()
