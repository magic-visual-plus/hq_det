# %%
from hq_det.models.rfdetr.datasets.coco import make_coco_transforms
from raw_utils import RFDETRTransformTracker
from raw_utils import flatten_transforms
# 创建跟踪器
tracker = RFDETRTransformTracker(
    dataset_dir="/root/autodl-tmp/chengdu_v2_dataset",
)
# 定义transforms
train_transforms = make_coco_transforms('train', 1008, False)

train_transforms = flatten_transforms(train_transforms)

# %%
res = tracker('train', 1275, train_transforms)
# Out:
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!

# %%
tracker.visualize_transforms(res)
