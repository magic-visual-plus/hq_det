# %% [markdown]
# # rtmdet

# %%
import os
os.chdir('/root/hq_det')

# %% [markdown]
# ## my

# %%
# !python scripts/run_train_rtmdet.py \
    --data_path /root/autodl-tmp/chengdu_v2_dataset \
    --output_path /root/autodl-tmp/rtmdet/output \
    --load_checkpoint /root/autodl-tmp/model/rtmdet/rtmdet_l_8xb32-300e_coco_20220719_112030-5a0be7c4.pth \
    --num_epoches 10 \
    --warmup_epochs 2 \
    --num_data_workers 8 \
    --lr0 1e-3 \
    --lr_min 5e-5 \
    --batch_size 4 \
    --device cuda:0 \
    --checkpoint_interval -1 \
    --image_size 1024
# Out:
# 2025-06-03 22:00:40.110 | INFO     | hq_det.trainer:run:191 - data_path='/root/autodl-tmp/chengdu_v2_dataset' num_epoches=10 warmup_epochs=2 num_data_workers=8 lr0=0.001 lr_min=5e-05 lr_backbone_mult=0.1 batch_size=4 device='cuda:0' checkpoint_path='/root/autodl-tmp/rtmdet/output' output_path='/root/autodl-tmp/rtmdet/output' checkpoint_interval=-1 model_argument={'model': '/root/autodl-tmp/model/rtmdet/rtmdet_l_8xb32-300e_coco_20220719_112030-5a0be7c4.pth'} image_size=1024 enable_amp=False gradient_update_interval=1 class_id2names=None eval_class_names=['划伤', '划痕', '压痕', '吊紧', '异物外漏', '折痕', '抛线', '拼接间隙', '烫伤', '爆针线', '破损', ' 碰伤', '线头', '脏污', '褶皱(贯穿)', '褶皱（轻度）', '褶皱（重度）', '重跳针'] devices=[0]
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# 2025-06-03 22:00:40.144 | INFO     | hq_det.dataset:__init__:118 - CocoDetection: img_folder /root/autodl-tmp/chengdu_v2_dataset/train using 3204 images
# ...
